# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset("tips")

# Create a KDE plot for the "total_bill" column
sns.kdeplot(data=tips["total_bill"])
plt.show()
